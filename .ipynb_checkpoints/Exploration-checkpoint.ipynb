# %%
import os
from dotenv import load_dotenv
from notion_client import Client
import json
import pandas as pd

# %%
load_dotenv()
# Out:
# True

# %%
notion_token= os.getenv("NOTION_TOKEN")
datasource_id= os.getenv("DATA_SOURCE_ID")
#initialiser le client notion
notion = Client(auth= notion_token, datasource_id)

# %%
print(datasource_id)
# Out:
# None

# %%
response = notion.users.list()
print(response.get('results'))

# %% [raw]
# response = notion.data_sources.retrieve(data_source_id=datasource_id)

# %%
#results = response.get('results')
#print(json.dumps(response, indent=2))

# %%
response = notion.data_sources.query(data_source_id=datasource_id)
# Out:
# ---------------------------------------------------------------------------
# HTTPStatusError                           Traceback (most recent call last)
# File ~/dev/notionlearning/venv/lib/python3.12/site-packages/notion_client/client.py:151, in BaseClient._parse_response(self, response)
#     150 try:
# --> 151     response.raise_for_status()
#     152 except httpx.HTTPStatusError as error:
#
# File ~/dev/notionlearning/venv/lib/python3.12/site-packages/httpx/_models.py:829, in Response.raise_for_status(self)
#     828 message = message.format(self, error_type=error_type)
# --> 829 raise HTTPStatusError(message, request=request, response=self)
#
# HTTPStatusError: Client error '400 Bad Request' for url 'https://api.notion.com/v1/data_sources/None/query'
# For more information check: https://developer.mozilla.org/en-US/docs/Web/HTTP/Status/400
#
# During handling of the above exception, another exception occurred:
#
# APIResponseError                          Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 response = notion.data_sources.query(data_source_id=datasource_id)
#
# File ~/dev/notionlearning/venv/lib/python3.12/site-packages/notion_client/api_endpoints.py:185, in DataSourcesEndpoint.query(self, data_source_id, **kwargs)
#     180 def query(self, data_source_id: str, **kwargs: Any) -> SyncAsync[Any]:
#     181     """Get a list of [Pages](https://developers.notion.com/reference/page) and/or [Data Sources](https://developers.notion.com/reference/data-source) contained in the data source.
#     182
#     183     *[🔗 Endpoint documentation](https://developers.notion.com/reference/query-a-data-source)*
#     184     """  # noqa: E501
# --> 185     return self.parent.request(
#     186         path=f"data_sources/{data_source_id}/query",
#     187         method="POST",
#     188         query=pick(kwargs, "filter_properties"),
#     189         body=pick(
#     190             kwargs,
#     191             "sorts",
#     192             "filter",
#     193             "start_cursor",
#     194             "page_size",
#     195             "archived",
#     196             "in_trash",
#     197             "result_type",
#     198         ),
#     199         auth=kwargs.get("auth"),
#     200     )
#
# File ~/dev/notionlearning/venv/lib/python3.12/site-packages/notion_client/client.py:239, in Client.request(self, path, method, query, body, form_data, auth)
#     237 except httpx.TimeoutException:
#     238     raise RequestTimeoutError()
# --> 239 return self._parse_response(response)
#
# File ~/dev/notionlearning/venv/lib/python3.12/site-packages/notion_client/client.py:163, in BaseClient._parse_response(self, response)
#     161         request_id = None
#     162     if code and is_api_error_code(code):
# --> 163         raise APIResponseError(
#     164             response,
#     165             body["message"],
#     166             code,
#     167             additional_data,
#     168             request_id,
#     169         )
#     170     raise HTTPResponseError(error.response)
#     172 body = response.json()
#
# APIResponseError: path failed validation: path.data_source_id should be a valid uuid, instead was `"None"`.
